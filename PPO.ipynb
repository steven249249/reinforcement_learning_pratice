# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.distributions as distributions

import matplotlib.pyplot as plt
import numpy as np
import gym

# %%
train_env = gym.make('LunarLander-v2')
test_env = gym.make('LunarLander-v2')

# %%
SEED = 1234

train_env.seed(SEED);
test_env.seed(SEED+1);
np.random.seed(SEED);
torch.manual_seed(SEED);

# %%
#網路
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout = 0.1):
        super().__init__()
        
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.Dropout(dropout),
            nn.PReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.Dropout(dropout),
            nn.PReLU(),
            nn.Linear(hidden_dim, output_dim)
        )
        
    def forward(self, x):
        x = self.net(x)
        return x

# %%
class ActorCritic(nn.Module):
    def __init__(self, actor, critic):
        super().__init__()
        
        self.actor = actor
        self.critic = critic
        
    def forward(self, state):
        
        action_pred = self.actor(state)
        value_pred = self.critic(state)
        
        return action_pred, value_pred

# %%
INPUT_DIM = train_env.observation_space.shape[0]
HIDDEN_DIM = 128
OUTPUT_DIM = train_env.action_space.n

actor = MLP(INPUT_DIM, HIDDEN_DIM, OUTPUT_DIM)
critic = MLP(INPUT_DIM, HIDDEN_DIM, 1)

policy = ActorCritic(actor, critic)

# %%
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_normal_(m.weight)
        m.bias.data.fill_(0)

# %%
policy.apply(init_weights)
# Out:
# ActorCritic(
#   (actor): MLP(
#     (net): Sequential(
#       (0): Linear(in_features=8, out_features=128, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#       (2): PReLU(num_parameters=1)
#       (3): Linear(in_features=128, out_features=128, bias=True)
#       (4): Dropout(p=0.1, inplace=False)
#       (5): PReLU(num_parameters=1)
#       (6): Linear(in_features=128, out_features=4, bias=True)
#     )
#   )
#   (critic): MLP(
#     (net): Sequential(
#       (0): Linear(in_features=8, out_features=128, bias=True)
#       (1): Dropout(p=0.1, inplace=False)
#       (2): PReLU(num_parameters=1)
#       (3): Linear(in_features=128, out_features=128, bias=True)
#       (4): Dropout(p=0.1, inplace=False)
#       (5): PReLU(num_parameters=1)
#       (6): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )

# %%
LEARNING_RATE = 0.0005

optimizer = optim.Adam(policy.parameters(), lr = LEARNING_RATE)

# %%
def train(env, policy, optimizer, discount_factor, ppo_steps, ppo_clip):
        
    policy.train()
        
    states = []
    actions = []
    log_prob_actions = []
    values = []
    rewards = []
    done = False
    episode_reward = 0

    state = env.reset()

    while not done:

        state = torch.FloatTensor(state).unsqueeze(0)

        #append state here, not after we get the next state from env.step()
        states.append(state)
        
        action_pred, value_pred = policy(state)
                
        action_prob = F.softmax(action_pred, dim = -1)
                
        dist = distributions.Categorical(action_prob)
        
        action = dist.sample()
        
        log_prob_action = dist.log_prob(action)
        
        state, reward, done, _ = env.step(action.item())

        actions.append(action)
        log_prob_actions.append(log_prob_action)
        values.append(value_pred)
        rewards.append(reward)
        
        episode_reward += reward
    
    states = torch.cat(states)
    actions = torch.cat(actions)    
    log_prob_actions = torch.cat(log_prob_actions)
    values = torch.cat(values).squeeze(-1)
    
    returns = calculate_returns(rewards, discount_factor)
    advantages = calculate_advantages(returns, values)
    
    policy_loss, value_loss = update_policy(policy, states, actions, log_prob_actions, advantages, returns, optimizer, ppo_steps, ppo_clip)

    return policy_loss, value_loss, episode_reward

# %%
def calculate_returns(rewards, discount_factor, normalize = True):
    
    returns = []
    R = 0
    
    for r in reversed(rewards):
        R = r + R * discount_factor
        returns.insert(0, R)
        
    returns = torch.tensor(returns)
    
    if normalize:
        returns = (returns - returns.mean()) / returns.std()
        
    return returns

# %%
def calculate_advantages(returns, values, normalize = True):
    
    advantages = returns - values
    
    if normalize:
        
        advantages = (advantages - advantages.mean()) / advantages.std()
        
    return advantages

# %%
def update_policy(policy, states, actions, log_prob_actions, advantages, returns, optimizer, ppo_steps, ppo_clip):
    
    total_policy_loss = 0 
    total_value_loss = 0
    
    states = states.detach()
    actions = actions.detach()
    log_prob_actions = log_prob_actions.detach()
    advantages = advantages.detach()
    returns = returns.detach()
    
    for _ in range(ppo_steps):
                
        #get new log prob of actions for all input states
        action_pred, value_pred = policy(states)
        value_pred = value_pred.squeeze(-1)
        action_prob = F.softmax(action_pred, dim = -1)
        dist = distributions.Categorical(action_prob)
        
        #new log prob using old actions
        new_log_prob_actions = dist.log_prob(actions)
        
        policy_ratio = (new_log_prob_actions - log_prob_actions).exp()
                
        policy_loss_1 = policy_ratio * advantages
        policy_loss_2 = torch.clamp(policy_ratio, min = 1.0 - ppo_clip, max = 1.0 + ppo_clip) * advantages
        
        policy_loss = - torch.min(policy_loss_1, policy_loss_2).mean()
        
        value_loss = F.smooth_l1_loss(returns, value_pred).mean()
    
        optimizer.zero_grad()

        policy_loss.backward()
        value_loss.backward()

        optimizer.step()
    
        total_policy_loss += policy_loss.item()
        total_value_loss += value_loss.item()
    
    return total_policy_loss / ppo_steps, total_value_loss / ppo_steps

# %%
def evaluate(env, policy):
    
    policy.eval()
    
    rewards = []
    done = False
    episode_reward = 0

    state = env.reset()

    while not done:

        state = torch.FloatTensor(state).unsqueeze(0)

        with torch.no_grad():
        
            action_pred, _ = policy(state)

            action_prob = F.softmax(action_pred, dim = -1)
                
        action = torch.argmax(action_prob, dim = -1)
                
        state, reward, done, _ = env.step(action.item())

        episode_reward += reward
        
    return episode_reward

# %%
MAX_EPISODES = 1_000
DISCOUNT_FACTOR = 0.99
N_TRIALS = 25
REWARD_THRESHOLD = 200
PRINT_EVERY = 10
PPO_STEPS = 5
PPO_CLIP = 0.2

train_rewards = []
test_rewards = []

for episode in range(1, MAX_EPISODES+1):
    
    policy_loss, value_loss, train_reward = train(train_env, policy, optimizer, DISCOUNT_FACTOR, PPO_STEPS, PPO_CLIP)
    
    test_reward = evaluate(test_env, policy)
    
    train_rewards.append(train_reward)
    test_rewards.append(test_reward)
    
    mean_train_rewards = np.mean(train_rewards[-N_TRIALS:])
    mean_test_rewards = np.mean(test_rewards[-N_TRIALS:])
    
    if episode % PRINT_EVERY == 0:
        
        print(f'| Episode: {episode:3} | Mean Train Rewards: {mean_train_rewards:7.1f} | Mean Test Rewards: {mean_test_rewards:7.1f} |')
    
    if mean_test_rewards >= REWARD_THRESHOLD:
        
        print(f'Reached reward threshold in {episode} episodes')
        
        break
# Out:
# | Episode:  10 | Mean Train Rewards:  -175.8 | Mean Test Rewards:  -404.3 |
# | Episode:  20 | Mean Train Rewards:  -161.0 | Mean Test Rewards:  -291.3 |
# | Episode:  30 | Mean Train Rewards:  -141.4 | Mean Test Rewards:  -206.7 |
# | Episode:  40 | Mean Train Rewards:  -128.4 | Mean Test Rewards:  -260.6 |
# | Episode:  50 | Mean Train Rewards:  -115.6 | Mean Test Rewards:  -281.4 |
# | Episode:  60 | Mean Train Rewards:  -114.7 | Mean Test Rewards:  -775.6 |
# | Episode:  70 | Mean Train Rewards:  -124.5 | Mean Test Rewards: -1142.4 |
# | Episode:  80 | Mean Train Rewards:  -194.4 | Mean Test Rewards: -1469.0 |
# | Episode:  90 | Mean Train Rewards:  -181.1 | Mean Test Rewards: -1737.4 |
# | Episode: 100 | Mean Train Rewards:  -203.1 | Mean Test Rewards: -2151.5 |
# | Episode: 110 | Mean Train Rewards:  -168.4 | Mean Test Rewards: -1744.5 |
# | Episode: 120 | Mean Train Rewards:  -106.9 | Mean Test Rewards:  -953.3 |
# | Episode: 130 | Mean Train Rewards:  -104.9 | Mean Test Rewards:  -550.8 |
# | Episode: 140 | Mean Train Rewards:  -101.9 | Mean Test Rewards:  -343.2 |
# | Episode: 150 | Mean Train Rewards:   -82.9 | Mean Test Rewards:  -296.5 |
# | Episode: 160 | Mean Train Rewards:   -65.4 | Mean Test Rewards:  -274.2 |
# | Episode: 170 | Mean Train Rewards:   -45.1 | Mean Test Rewards:  -248.2 |
# | Episode: 180 | Mean Train Rewards:   -19.9 | Mean Test Rewards:  -234.6 |
# | Episode: 190 | Mean Train Rewards:    14.1 | Mean Test Rewards:  -254.4 |
# | Episode: 200 | Mean Train Rewards:    15.4 | Mean Test Rewards:  -212.9 |
# | Episode: 210 | Mean Train Rewards:    20.8 | Mean Test Rewards:  -186.6 |
# | Episode: 220 | Mean Train Rewards:    29.7 | Mean Test Rewards:  -128.6 |
# | Episode: 230 | Mean Train Rewards:    47.9 | Mean Test Rewards:   -98.8 |
# | Episode: 240 | Mean Train Rewards:    51.4 | Mean Test Rewards:   -87.7 |
# | Episode: 250 | Mean Train Rewards:    56.6 | Mean Test Rewards:  -123.0 |
# | Episode: 260 | Mean Train Rewards:    64.7 | Mean Test Rewards:  -114.2 |
# | Episode: 270 | Mean Train Rewards:    72.3 | Mean Test Rewards:   -67.7 |
# | Episode: 280 | Mean Train Rewards:    45.2 | Mean Test Rewards:   -71.7 |
# | Episode: 290 | Mean Train Rewards:    28.9 | Mean Test Rewards:  -106.6 |
# | Episode: 300 | Mean Train Rewards:    50.2 | Mean Test Rewards:  -106.3 |
# | Episode: 310 | Mean Train Rewards:    79.0 | Mean Test Rewards:   -77.6 |
# | Episode: 320 | Mean Train Rewards:    81.3 | Mean Test Rewards:   -63.4 |
# | Episode: 330 | Mean Train Rewards:    60.7 | Mean Test Rewards:   -90.3 |
# | Episode: 340 | Mean Train Rewards:    61.9 | Mean Test Rewards:  -102.6 |
# | Episode: 350 | Mean Train Rewards:    54.3 | Mean Test Rewards:  -105.2 |
# | Episode: 360 | Mean Train Rewards:    56.9 | Mean Test Rewards:  -109.0 |
# | Episode: 370 | Mean Train Rewards:    36.8 | Mean Test Rewards:  -135.5 |
# | Episode: 380 | Mean Train Rewards:    38.6 | Mean Test Rewards:  -178.7 |
# | Episode: 390 | Mean Train Rewards:    55.1 | Mean Test Rewards:  -161.8 |
# | Episode: 400 | Mean Train Rewards:    73.1 | Mean Test Rewards:  -152.9 |
# | Episode: 410 | Mean Train Rewards:    76.0 | Mean Test Rewards:   -76.2 |
# | Episode: 420 | Mean Train Rewards:   100.8 | Mean Test Rewards:    42.1 |
# | Episode: 430 | Mean Train Rewards:    92.7 | Mean Test Rewards:    74.5 |
# | Episode: 440 | Mean Train Rewards:    67.0 | Mean Test Rewards:    13.1 |
# | Episode: 450 | Mean Train Rewards:    72.2 | Mean Test Rewards:   -30.1 |
# | Episode: 460 | Mean Train Rewards:    84.3 | Mean Test Rewards:   -36.4 |
# | Episode: 470 | Mean Train Rewards:    94.4 | Mean Test Rewards:   -32.1 |
# | Episode: 480 | Mean Train Rewards:    93.3 | Mean Test Rewards:   -12.9 |
# | Episode: 490 | Mean Train Rewards:    95.9 | Mean Test Rewards:   -21.7 |
# | Episode: 500 | Mean Train Rewards:    84.7 | Mean Test Rewards:   -64.6 |
# | Episode: 510 | Mean Train Rewards:    71.5 | Mean Test Rewards:   -70.0 |
# | Episode: 520 | Mean Train Rewards:    73.1 | Mean Test Rewards:   -41.2 |
# | Episode: 530 | Mean Train Rewards:   100.4 | Mean Test Rewards:     4.7 |
# | Episode: 540 | Mean Train Rewards:    95.5 | Mean Test Rewards:    20.8 |
# | Episode: 550 | Mean Train Rewards:    76.7 | Mean Test Rewards:    12.7 |
# | Episode: 560 | Mean Train Rewards:    65.9 | Mean Test Rewards:    -8.0 |
# | Episode: 570 | Mean Train Rewards:    80.2 | Mean Test Rewards:    -9.6 |
# | Episode: 580 | Mean Train Rewards:    95.9 | Mean Test Rewards:    -5.1 |
# | Episode: 590 | Mean Train Rewards:    70.9 | Mean Test Rewards:   -33.3 |
# | Episode: 600 | Mean Train Rewards:    66.1 | Mean Test Rewards:   -32.0 |
# | Episode: 610 | Mean Train Rewards:    72.8 | Mean Test Rewards:   -36.0 |
# | Episode: 620 | Mean Train Rewards:    68.8 | Mean Test Rewards:   -39.4 |
# | Episode: 630 | Mean Train Rewards:    88.7 | Mean Test Rewards:    -2.3 |
# | Episode: 640 | Mean Train Rewards:   116.3 | Mean Test Rewards:    50.8 |
# | Episode: 650 | Mean Train Rewards:   127.6 | Mean Test Rewards:    64.6 |
# | Episode: 660 | Mean Train Rewards:   114.3 | Mean Test Rewards:    87.1 |
# | Episode: 670 | Mean Train Rewards:   105.6 | Mean Test Rewards:    90.8 |
# | Episode: 680 | Mean Train Rewards:   104.7 | Mean Test Rewards:   101.9 |
# | Episode: 690 | Mean Train Rewards:   107.0 | Mean Test Rewards:    97.2 |
# | Episode: 700 | Mean Train Rewards:   106.0 | Mean Test Rewards:   101.3 |
# | Episode: 710 | Mean Train Rewards:    95.7 | Mean Test Rewards:    73.0 |
# | Episode: 720 | Mean Train Rewards:    87.7 | Mean Test Rewards:    24.1 |
# | Episode: 730 | Mean Train Rewards:    87.8 | Mean Test Rewards:     6.2 |
# | Episode: 740 | Mean Train Rewards:   106.2 | Mean Test Rewards:    36.9 |
# | Episode: 750 | Mean Train Rewards:   126.0 | Mean Test Rewards:    85.6 |
# | Episode: 760 | Mean Train Rewards:   108.4 | Mean Test Rewards:    73.9 |
# | Episode: 770 | Mean Train Rewards:    90.3 | Mean Test Rewards:    54.1 |
# | Episode: 780 | Mean Train Rewards:    70.6 | Mean Test Rewards:    32.2 |
# | Episode: 790 | Mean Train Rewards:    67.7 | Mean Test Rewards:    20.8 |
# | Episode: 800 | Mean Train Rewards:    87.1 | Mean Test Rewards:    40.4 |
# | Episode: 810 | Mean Train Rewards:   100.4 | Mean Test Rewards:    67.3 |
# | Episode: 820 | Mean Train Rewards:   106.9 | Mean Test Rewards:    74.5 |
# | Episode: 830 | Mean Train Rewards:   103.7 | Mean Test Rewards:    81.2 |
# | Episode: 840 | Mean Train Rewards:    91.1 | Mean Test Rewards:    95.8 |
# | Episode: 850 | Mean Train Rewards:    89.1 | Mean Test Rewards:    93.1 |
# | Episode: 860 | Mean Train Rewards:    95.8 | Mean Test Rewards:    84.4 |
# | Episode: 870 | Mean Train Rewards:   103.7 | Mean Test Rewards:    75.8 |
# | Episode: 880 | Mean Train Rewards:    98.2 | Mean Test Rewards:    58.5 |
# | Episode: 890 | Mean Train Rewards:    89.2 | Mean Test Rewards:    46.7 |
# | Episode: 900 | Mean Train Rewards:    87.9 | Mean Test Rewards:    57.6 |
# | Episode: 910 | Mean Train Rewards:    98.3 | Mean Test Rewards:    62.7 |
# | Episode: 920 | Mean Train Rewards:   107.5 | Mean Test Rewards:    67.8 |
# | Episode: 930 | Mean Train Rewards:   110.6 | Mean Test Rewards:   121.8 |
# | Episode: 940 | Mean Train Rewards:   111.8 | Mean Test Rewards:   178.8 |
# Reached reward threshold in 946 episodes

# %%
plt.figure(figsize=(12,8))
plt.plot(test_rewards, label='Test Reward')
plt.plot(train_rewards, label='Train Reward')
plt.xlabel('Episode', fontsize=20)
plt.ylabel('Reward', fontsize=20)
plt.hlines(REWARD_THRESHOLD, 0, len(test_rewards), color='r')
plt.legend(loc='lower right')
plt.grid()
